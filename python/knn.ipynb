# %%
import pandas as pd
import numpy as np

# %%
orders_df = pd.read_json('orders.json')
prod_df = pd.read_json('products.json')
cat_df = pd.read_json('categories.json')

# %%
orders_df
# Out:
#        id       date first_name last_name                       email  \
# 0       1 1981-06-25    Russell    Bryant  kristinaharmon@example.org
# 1       2 2002-11-03      Julia    Castro   kaylamartinez@example.net
# 2       3 1981-07-29    Michael    Bryant     edwardhurst@example.org
# 3       4 2007-06-13  Francisco      Sims       ghatfield@example.com
# 4       5 2019-02-15      David  Robinson       michele20@example.com
# ..    ...        ...        ...       ...                         ...
# 995   996 2014-02-10       Todd    Nelson    allencrystal@example.com
# 996   997 1991-05-23    Michael     Lloyd         smorgan@example.org
# 997   998 2011-08-12       Eric  Hamilton          iriggs@example.net
# 998   999 2014-01-20       Earl    Hughes   richardgamble@example.com
# 999  1000 2020-11-27    Matthew    Wilson  michellemiller@example.com
#
#                            address       credit_card  \
# 0      3846 Janet Cliffs Suite 736  6587318701441683
# ...

# %%
prod_df
# Out:
#     id           name               description     price  inventory_count  \
# 0    1       recorder   Uncert behavior neo NEC  $3603.17               98
# 1    2    delay pedal   Posterior pole scar NEC  $4469.35               88
# 2    3    small strap  Simp schiz-subchr/exacer  $2743.31               40
# 3    4   medium strap  Cl skl w oth fx-mod coma  $3230.43               91
# 4    5    large strap   Metatarsus primus varus  $3099.98               73
# ..  ..            ...                       ...       ...              ...
# 65  66  trombone case   Posterior disloc hip-cl  $1719.60               51
# 66  67   trumpet case    Cellulitis, finger NOS   $306.96               92
# 67  68  keyboard case    Excess cry infant/baby   $184.49               34
# 68  69  small speaker  Sus cervcl shortn nt fnd   $874.58               50
# 69  70  large speaker   Inj nerve shldr/arm NOS  $2007.01               91
#
#        category
# 0       guitars
# 1       guitars
# ...

# %%
cat_df
# Out:
#    id         name                                           products
# 0   1      Strings                    [4, 10, 12, 16, 22, 38, 58, 60]
# 1   2      Guitars                             [1, 2, 17, 31, 37, 69]
# 2   3       Basses                     [7, 8, 21, 30, 49, 65, 67, 68]
# 3   4   Percussion                               [24, 26, 32, 43, 46]
# 4   5        Tools                                    [5, 19, 36, 66]
# 5   6  Accessories        [6, 29, 33, 39, 45, 47, 48, 56, 57, 61, 70]
# 6   7        Brass                        [9, 14, 15, 28, 34, 40, 53]
# 7   8     Stickers                    [3, 11, 13, 23, 27, 52, 54, 62]
# 8   9    Woodwinds  [18, 20, 25, 35, 41, 42, 44, 50, 51, 55, 59, 6...
